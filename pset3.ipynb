# %% [markdown]
# # Problem Set 3: Symbolic AI

# %% [markdown]
# ## Q1 [Total: 17 points]

# %% [markdown]
# ### Q1a. [6 points]

# %% [markdown]
# Use a truth table to show that ¬(p∨¬(p∧q)) is a contradiction.

# %% [markdown]
#     p    q     (p∧q)    ¬(p∧q)   p∨¬(p∧q)    ¬(p∨¬(p∧q))
#
#     T    T       T         F         T             F
#     T    F       F         T         T             F
#     F    T       F         T         T             F
#     F    F       F         T         T             F

# %% [markdown]
# ### Q1b. [6 points]

# %% [markdown]
# Prove that ((p → q)∧ ¬q)→ ¬p is a tautology using propositional equivalencies.

# %% [markdown]
#     p   q    (p → q)    ¬q    (p → q)∧ ¬q      ¬p      ((p → q)∧ ¬q)→ ¬p
#
#     T   T       T        F          F           F             T
#     T   F       F        T          F           F             T
#     F   T       T        F          F           T             T
#     F   F       T        T          T           T             T

# %% [markdown]
# ### Q1c. [5 points]

# %% [markdown]
# Using a depth-first search, list all the nodes that will be visited to solve the satisfiability problem using the following clauses to be satisfied:  ¬a ∨ b and ¬b ∨ c.

# %% [markdown]
# ![tree](./tree.png)

# %% [markdown]
# Using a depth-first search
#
# We get the answer:
#
# LMOS
#
# L -> M -> O -> S

# %% [markdown]
# ## Q2 [Total: 10 points]

# %% [markdown]
# Answer the following questions about the search problem shown below. Break any ties alphabetically. For the questions that ask for a path, please give your answers in the form ‘S − A − D − G’ where S is the start state and G is the goal state.

# %% [markdown]
# ![graph](./graph.png)

# %% [markdown]
# ### Q2a. [2 points]

# %% [markdown]
# What path would breadth-first search return for this search problem?

# %% [markdown]
# S − G

# %% [markdown]
# ### Q2b. [2 points]

# %% [markdown]
# What path would uniform cost search return for this search problem?

# %% [markdown]
# What path would uniform cost search return for this search problem

# %% [markdown]
# S − A − C − G

# %% [markdown]
# ### Q2c. [2 points]

# %% [markdown]
# Which of the following two heuristics, h_1 and h_2, is admissible? Why?

# %% [markdown]
# ![heuristic](./heuristic.png)

# %% [markdown]
# An admissible heuristic must underestimate or be equal to the true cost.
#
# Thus,
# h_2 is admissible because h_2 does not overestimate costs and is admissible.

# %% [markdown]
# ### Q2d. [2 points]

# %% [markdown]
# What path would greedy search follow using the admissible heuristic from c) above?

# %% [markdown]
# S - A - C - G

# %% [markdown]
# ### Q2e. [2 points]

# %% [markdown]
# What path would the A* search follow using the admissible heuristic from c) above?

# %% [markdown]
# S - A - C - G

# %% [markdown]
# ## Q3 [Total: 14 points]

# %% [markdown]
# Suppose we want to schedule some final exams for CS courses with the following course numbers: 1007, 3137, 3157, 3203, 3261, 4115, 4118, 4156
#
# Suppose also that there are no students in common taking the following pairs of courses:
#
# 1007‐3137
#
# 1007‐3157, 3137‐3157
#
# 1007‐3203
#
# 1007‐3261, 3137‐3261, 3203‐3261
#
# 1007‐4115, 3137‐4115, 3203‐4115, 3261‐4115
#
# 1007‐4118, 3137‐4118
#
# 1007‐4156, 3137‐4156, 3157‐4156

# %% [markdown]
# ### Q3a. [4 points]

# %% [markdown]
# What type of AI problem can this be mapped to? What is the mapping

# %% [markdown]
# We can map this type of AI problem to Constraint Satisfaction Problem.
#
# The mapping will be
#
# Variable: examslots{i}
#
# Domain: {1007, 3137, 3157, 3203, 3261, 4115, 4118, 4156}
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Q3b. [10 points]

# %% [markdown]
# How many exam slots are necessary to schedule exams?

# %% [markdown]
#     We need 3 exam slots in order to schedule the exams.
#
#     Monday - 3137, 3157, 1007, 4156
#     Tuesday - 3203, 3261, 4115
#     Wednesday - 4118

# %% [markdown]
# ## Q4 [Total: 9 points]

# %% [markdown]
# ### Q4a. [3 points]

# %% [markdown]
# List the main benefits and limitations of Symbolic AI.

# %% [markdown]
#       Main Limitations:
#        1. Symbolic AI starts to break when you must deal
#           with the messiness of the world,
#        2. Example: Computer Vision the science of enabling computers to make sense
#           of the content of images and video,
#        3. Case Study: Say you have a picture of your cat and want to create a program that can detect images that               contain your cat.
#            • You create a rule-based program that:
#            • takes new images as inputs
#            • compares the pixels to the original cat image
#            • responds by saying whether your cat is in those images
#            • Problem: This will only work if you provide an exact copy
#              of the original image to your program!
#            • A slightly different picture of your cat will yield a
#             negative answer. Example: if you take a picture of your
#             cat from a different angle, the program will fail.
#            Conclusion:
#                         You cannot define rules for the messy data that
#                         exists in the real world, e.g. how can you define the
#                         rules for a self-driving car to detect all the different
#                         pedestrians it might face?
#
#
#     Main Benefits:
#        1. We can easily visualize the logic of rule-based programs, communicate them, and troubleshoot them.
#        2. Explainable

# %% [markdown]
# ### Q4b. [3 points]

# %% [markdown]
# List the main benefits and limitation(s) of Neural Networks.

# %% [markdown]
#     Main Limitations:
#        1. It is often very difficult to interpret and investigate the output
#         of neural networks. This is especially troublesome for
#         domains where explainability of automated decisions is
#         a legal requirement.
#        2. Neural networks have no notion of symbols and hierarchical
#         representation of knowledge. This limitation makes it very
#         hard to apply neural networks to tasks that require logic and
#         reasoning.
#        3. Neural networks are very data-hungry.
#        4. Neural networks can also become the target of adversarial
#         examples: carefully crafted pieces of data that manipulate
#         the behavior of AI models in erratic or malicious ways.
#
#     Main Benefits:
#        1. They can deal with messy and unstructured data.
#             -Instead of manually laboring through the rules of
#             detecting cat pixels, you can train a deep learning
#             algorithm on many pictures of cats (and dogs etc.).
#             -The neural network then develops a statistical
#             model for cat images.
#             -When you provide it with a new image, it will
#             return the probability that it contains a cat.
#        2. NNs created a revolution in computer vision applications
#            such as facial recognition and cancer detection
#        3. Deep learning has also driven advances in languagerelated tasks
#        4. Deep NNs are also very suitable for reinforcement
#            learning, AI models that develop their behavior through
#            numerous trial and error. This is the kind of AI that
#            masters complicated games such as Go, StarCraft, Data.

# %% [markdown]
# ### Q4c. [3 points]

# %% [markdown]
# What is the main motivation behind combining Neural Networks and Symbolic AI in recent approaches?

# %% [markdown]
#     There are now several efforts to combine neural networks
#     and symbolic AI. One such project is the Neuro-Symbolic Concept Learner
#     (NSCL), a hybrid AI system developed by the MIT-IBM Watson
#     AI Lab –ICLR’19. NSCL uses both rule-based programs and neural networks to
#     solve visual question-answering problems
#
#     + As opposed to pure NN–based models, the hybrid AI can
#     learn new tasks with less data and is explainable
#     + And unlike symbolic-only models, NSCL doesn’t struggle to
#     analyze the content of images.
#
#     Motivation:
#         1. One of the biggest is to be able to automatically encode better rules for symbolic AI.
#         2. Another benefit of combining the techniques lies in making the AI model easier to understand.
